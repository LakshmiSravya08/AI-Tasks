# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( "Axisbank.csv" )
df
# Out:
#             Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0     2000-01-03   UTIBANK     EQ       24.70   26.7   26.70   26.70   26.70
# 1     2000-01-04   UTIBANK     EQ       26.70   27.0   28.70   26.50   27.00
# 2     2000-01-05   UTIBANK     EQ       26.85   26.0   27.75   25.50   26.40
# 3     2000-01-06   UTIBANK     EQ       26.30   25.8   27.00   25.80   25.90
# 4     2000-01-07   UTIBANK     EQ       25.95   25.0   26.00   24.25   25.00
# ...          ...       ...    ...         ...    ...     ...     ...     ...
# 5301  2021-04-26  AXISBANK     EQ      671.35  694.0  703.80  684.50  699.50
# 5302  2021-04-27  AXISBANK     EQ      700.45  691.1  703.90  684.10  700.90
# 5303  2021-04-28  AXISBANK     EQ      699.55  708.0  712.50  688.15  705.95
# 5304  2021-04-29  AXISBANK     EQ      708.15  712.0  726.90  707.00  717.10
# 5305  2021-04-30  AXISBANK     EQ      719.40  705.0  729.85  705.00  711.65
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 0      26.70   26.70    112100  2.993070e+11       NaN                 NaN
# 1      26.85   27.24    234500  6.387275e+11       NaN                 NaN
# 2      26.30   26.24    170100  4.462980e+11       NaN                 NaN
# 3      25.95   26.27    102100  2.681730e+11       NaN                 NaN
# 4      24.80   25.04     62600  1.567220e+11       NaN                 NaN
# ...      ...     ...       ...           ...       ...                 ...
# 5301  700.45  695.33  21646184  1.505120e+15  286480.0           5949937.0
# 5302  699.55  692.83  46559967  3.225830e+15  289445.0          18080082.0
# 5303  708.15  701.92  54060587  3.794635e+15  507747.0          17851331.0
# 5304  719.40  717.41  25939327  1.860920e+15  312079.0           7357520.0
# 5305  714.90  719.36  23011654  1.655365e+15  232879.0           6786072.0
#
#       %Deliverble
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 5301       0.2749
# 5302       0.3883
# 5303       0.3302
# 5304       0.2836
# 5305       0.2949
#
# [5306 rows x 15 columns]

# %%
df = df.truncate(after = 30)
df
# Out:
#           Date   Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0   2000-01-03  UTIBANK     EQ       24.70  26.70  26.70  26.70  26.70  26.70
# 1   2000-01-04  UTIBANK     EQ       26.70  27.00  28.70  26.50  27.00  26.85
# 2   2000-01-05  UTIBANK     EQ       26.85  26.00  27.75  25.50  26.40  26.30
# 3   2000-01-06  UTIBANK     EQ       26.30  25.80  27.00  25.80  25.90  25.95
# 4   2000-01-07  UTIBANK     EQ       25.95  25.00  26.00  24.25  25.00  24.80
# 5   2000-01-10  UTIBANK     EQ       24.80  25.05  26.50  25.00  25.00  25.00
# 5   25.29   64200  1.623340e+11     NaN                 NaN          NaN
# 6   23.90   91700  2.191725e+11     NaN                 NaN          NaN
# 7   23.97   32500  7.791350e+10     NaN                 NaN          NaN
# 8   23.77   48300  1.147955e+11     NaN                 NaN          NaN
# 9   23.17   30700  7.114250e+10     NaN                 NaN          NaN
# 10  25.09   82400  2.067375e+11     NaN                 NaN          NaN
# 11  24.94  110400  2.753805e+11     NaN                 NaN          NaN
# 12  25.56   89300  2.282665e+11     NaN                 NaN          NaN
# 13  25.05  103500  2.592305e+11     NaN                 NaN          NaN
# 14  24.79   47300  1.172575e+11     NaN                 NaN          NaN
# 15  25.03  102400  2.562690e+11     NaN                 NaN          NaN
# 16  24.90  131700  3.278985e+11     NaN                 NaN          NaN
# 17  26.80  201400  5.397455e+11     NaN                 NaN          NaN
# 18  29.04  311600  9.050250e+11     NaN                 NaN          NaN
# 19  31.45  317000  9.969930e+11     NaN                 NaN          NaN
# 20  34.11  201000  6.855690e+11     NaN                 NaN          NaN
# 21  36.90   65800  2.428020e+11     NaN                 NaN          NaN
# 22  39.85  160400  6.391940e+11     NaN                 NaN          NaN
# 23  43.05   60700  2.613135e+11     NaN                 NaN          NaN
# 24  40.95  790600  3.237276e+12     NaN                 NaN          NaN
# 25  37.91  434100  1.645559e+12     NaN                 NaN          NaN
# 26  36.78  284200  1.045190e+12     NaN                 NaN          NaN
# 27  38.34  214000  8.203855e+11     NaN                 NaN          NaN
# 28  42.10  129700  5.460370e+11     NaN                 NaN          NaN
# 29  40.38  236000  9.530540e+11     NaN                 NaN          NaN
# 30  36.16  285600  1.032644e+12     NaN                 NaN          NaN

# %%
b_plot = sns.barplot( x = df["Date"], y = df["Volume"] )
plt.draw()
b_plot.set_xticklabels( b_plot.get_xticklabels() , rotation = 90 )
print()

# %%
h_plot = sns.histplot( x = df["Date"], y = df["High"] )
plt.draw()
h_plot.set_xticklabels( h_plot.get_xticklabels() , rotation = 90 )
print()
# Out:
# C:\Users\Sravy\AppData\Local\Temp/ipykernel_12184/4013549849.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   h_plot.set_xticklabels( h_plot.get_xticklabels() , rotation = 90 )

# %%
sc_plot = sns.scatterplot( x = df["Date"], y = df["Low"] )
plt.draw()
sc_plot.set_xticklabels( sc_plot.get_xticklabels() , rotation = 90 )
print()
# Out:
# C:\Users\Sravy\AppData\Local\Temp/ipykernel_12184/4216932042.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sc_plot.set_xticklabels( sc_plot.get_xticklabels() , rotation = 90 )

# %%
df.corr() 

sns.heatmap( df.isnull()  )
# Out:
# <AxesSubplot:>
